# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install keras-tuner --upgrade
import pandas as pd
import numpy as np
import os
from numpy import concatenate
import matplotlib.pyplot as plt
import seaborn as sns
from keras.preprocessing.sequence import TimeseriesGenerator
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense, Dropout, LSTM, CuDNNLSTM, BatchNormalizationV2, TimeDistributed, RepeatVector, Reshape,BatchNormalization,Activation,Flatten,Conv1D, MaxPooling1D
from keras.callbacks import EarlyStopping, ModelCheckpoint
from keras.optimizers import Adam
from keras_tuner.tuners import RandomSearch, Hyperband, gridsearch
from keras.utils.vis_utils import plot_model
from datetime import date, datetime
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_squared_error, mean_absolute_error,mean_absolute_percentage_error
from sklearn.metrics import accuracy_score
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectKBest,chi2
from sklearn.feature_selection import f_regression
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from keras.optimizers import Adam, RMSprop, Adagrad,SGD
from statsmodels.tsa.stattools import adfuller
# Out:
# Collecting keras-tuner
#   Downloading keras_tuner-1.3.5-py3-none-any.whl (176 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 176.1/176.1 kB 3.8 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (23.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from keras-tuner) (2.31.0)
# Collecting kt-legacy (from keras-tuner)
#   Downloading kt_legacy-1.0.5-py3-none-any.whl (9.6 kB)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.2.0)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->keras-tuner) (2023.7.22)
# Installing collected packages: kt-legacy, keras-tuner
# Successfully installed keras-tuner-1.3.5 kt-legacy-1.0.5

# %%
def first_prep(data_path):
  data=pd.read_csv(data_path)
  data["Time(year-month-day h:m:s)"] = pd.to_datetime(data["Time(year-month-day h:m:s)"])
  data= data.sort_values(by='Time(year-month-day h:m:s)', ascending=True)
  data.set_index('Time(year-month-day h:m:s)', inplace=True)
  return data

# %%
solar_data=first_prep('/content/drive/MyDrive/PV_Wind_Power_Forecasting_Hmidani_Hicham/Solar-station-site-1-_Nominal-capacity-50MW_.csv')
wind_data=first_prep('/content/drive/MyDrive/PV_Wind_Power_Forecasting_Hmidani_Hicham/Wind-farm-site-1-_Nominal-capacity-99MW_-_1_.csv')

# %% [markdown]
# **Approche univariée**

# %%
Solar_Power=solar_data[['Power (MW)']].copy()
Wind_Power=wind_data[['Power (MW)']].copy()

#Split the data into train and test for solar data
train_S=Solar_Power[:int(len(solar_data)*0.8)]
test_S=Solar_Power[int(len(solar_data)*0.8):]
#Split the data into train and test
train_W=Wind_Power[:int(len(wind_data)*0.8)]
test_W=Wind_Power[int(len(wind_data)*0.8):]

def Scaler(train,test):
 sc1=StandardScaler()
 sc2=StandardScaler()
 train_scaled=sc1.fit_transform(train)
 test_scaled=sc2.fit_transform(test)
 return train_scaled,test_scaled,sc1,sc2

train_S,test_S,sc_train_S,sc_test_S=Scaler(train_S,test_S)
train_W,test_W,sc_train_W,sc_test_W=Scaler(train_W,test_W)

#split to sequence for determine the step_inputs and the step_outputs

def split_sequences(df,step_in=960,step_out=24):
 X,y=[],[]
 for i in range(step_in,len(df)-step_out):
  X.append(df[i-step_in:i])
  y.append(df[i:i+step_out])
 X=np.array(X)
 y=np.array(y)
 return X,y

X_train_S,y_train_S=split_sequences(train_S,step_in=96,step_out=24)
X_test_S,y_test_S=split_sequences(test_S,step_in=96,step_out=24)
X_train_W,y_train_W=split_sequences(train_W,step_in=96,step_out=24)
X_test_W,y_test_W=split_sequences(test_W,step_in=96,step_out=24)

def get_best_model(X_train,y_train,max_trials=10,executions_per_trial=1,project_name='univariate_Forecasting_CNNLSTM'):

  def CNNLSTM_model(hp):

   model=Sequential()
   model.add(Conv1D(hp.Int('filter_1',16,64,16),hp.Int('kernel_size_1',1,3,1),activation='relu',input_shape=(X_train.shape[1],X_train.shape[2])))
   model.add(MaxPooling1D(hp.Int('pool_size',1,3,1)))
   model.add(Conv1D(hp.Int('filter_2',16,64,16),hp.Int('kernel_size_2',1,3,1)))
   model.add(MaxPooling1D(hp.Int('pool_size',1,3,1)))
   model.add(CuDNNLSTM(hp.Int('unit_1',50,150,50),return_sequences=True))
   model.add(Activation('relu'))
   model.add(CuDNNLSTM(hp.Int('unit_2',50,150,50)))
   model.add(Dense(y_train_S.shape[1]))
   batch_size_=hp.Int('batch_size',32,64,16)
   epochs=hp.Int('epochs',5,20,5)
   model.compile(optimizer='adam',loss='mae',metrics=['mae','mse'])

   return model


  tuner = RandomSearch(CNNLSTM_model, max_trials=max_trials, objective='mse', executions_per_trial=executions_per_trial, directory='solar_wind_power_forecasting', project_name=project_name)
  es = EarlyStopping(monitor='mse', patience=5, mode='min', verbose=1, restore_best_weights = True)
  cp = ModelCheckpoint(filepath='best_model.h5', save_best_only=True, save_weights_only=True, monitor='mse', mode='min', verbose=1)
  tuner.search(X_train, y_train, verbose=1,batch_size=32,validation_split=0.2,callbacks=[cp,es],shuffle=False)
  #Get the best_hyperpameters
  best_hyp = tuner.get_best_hyperparameters()[0]
  model = tuner.hypermodel.build(best_hyp)
  model_summary=model.summary()
  history = model.fit(X_train, y_train, validation_split=0.2, epochs=best_hyp.get('epochs'), batch_size=best_hyp.get('batch_size'), callbacks=[cp,es], verbose=1,shuffle=False)
  #model_trained= tuner.get_best_models(num_models=1)[0]

  return history,model,model_summary

# %%
import tensorflow as tf
def save_model(model,model_path):
  if os.path.exists(model_path):
    os.remove(model_path)
    print(f"Deleted existing model: {model_path}")
    model.save(model_path)
  else:
    print(f"No existing model found at: {model_path}")
    model.save(model_path)

def load_model(model_path):
  loaded_model = tf.keras.models.load_model(model_path)
  return loaded_model

# %%
def history_model(model):
    plt.figure(1)
    plt.plot(model.history['mae'])
    plt.plot(model.history['val_mae'])
    plt.title('mae & val_mae')
    plt.legend(['mae', 'val_mae'])
    plt.show()

    plt.figure(2)
    plt.plot(model.history['mse'])
    plt.plot(model.history['val_mse'])
    plt.title('mse & val_mse')
    plt.legend(['mse', 'val_mse'])
    plt.show()

# %%
history_u_CNNLSTM_S,model_u_CNNLSTM_S,model_summary=get_best_model(X_train_S,y_train_S,project_name='solar power foreacasting_unvariate_CNNLSTM_1')
model_summary
# Out:
# Trial 10 Complete [00h 00m 23s]
# mse: 0.27482515573501587
#
# Best mse So Far: 0.2431330382823944
# Total elapsed time: 00h 04m 12s
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 96, 48)            96
#
#  max_pooling1d_2 (MaxPooling  (None, 96, 48)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 95, 64)            6208
#
#  max_pooling1d_3 (MaxPooling  (None, 95, 64)           0
#  1D)
#
#  cu_dnnlstm_2 (CuDNNLSTM)    (None, 95, 100)           66400
#
#  activation_1 (Activation)   (None, 95, 100)           0
#
#  cu_dnnlstm_3 (CuDNNLSTM)    (None, 100)               80800
#
#  dense_1 (Dense)             (None, 24)                2424
#
# =================================================================
# Total params: 155,928
# Trainable params: 155,928
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/10
# 1397/1401 [============================>.] - ETA: 0s - loss: 0.3806 - mae: 0.3806 - mse: 0.4868
# Epoch 1: mse improved from inf to 0.48583, saving model to best_model.h5
# 1401/1401 [==============================] - 22s 13ms/step - loss: 0.3802 - mae: 0.3802 - mse: 0.4858 - val_loss: 0.4024 - val_mae: 0.4024 - val_mse: 0.4680
# Epoch 2/10
# 1400/1401 [============================>.] - ETA: 0s - loss: 0.2416 - mae: 0.2416 - mse: 0.2127
# Epoch 2: mse improved from 0.48583 to 0.21261, saving model to best_model.h5
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.2415 - mae: 0.2415 - mse: 0.2126 - val_loss: 0.2674 - val_mae: 0.2674 - val_mse: 0.2934
# Epoch 3/10
# 1397/1401 [============================>.] - ETA: 0s - loss: 0.2014 - mae: 0.2014 - mse: 0.1636
# Epoch 3: mse improved from 0.21261 to 0.16336, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.2012 - mae: 0.2012 - mse: 0.1634 - val_loss: 0.2686 - val_mae: 0.2686 - val_mse: 0.2951
# Epoch 4/10
# 1401/1401 [==============================] - ETA: 0s - loss: 0.1899 - mae: 0.1899 - mse: 0.1511
# Epoch 4: mse improved from 0.16336 to 0.15109, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.1899 - mae: 0.1899 - mse: 0.1511 - val_loss: 0.2665 - val_mae: 0.2665 - val_mse: 0.2847
# Epoch 5/10
# 1401/1401 [==============================] - ETA: 0s - loss: 0.1915 - mae: 0.1915 - mse: 0.1547
# Epoch 5: mse did not improve from 0.15109
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.1915 - mae: 0.1915 - mse: 0.1547 - val_loss: 0.2571 - val_mae: 0.2571 - val_mse: 0.2737
# Epoch 6/10
# 1397/1401 [============================>.] - ETA: 0s - loss: 0.1821 - mae: 0.1821 - mse: 0.1450
# Epoch 6: mse improved from 0.15109 to 0.14476, saving model to best_model.h5
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.1819 - mae: 0.1819 - mse: 0.1448 - val_loss: 0.2624 - val_mae: 0.2624 - val_mse: 0.2771
# Epoch 7/10
# 1401/1401 [==============================] - ETA: 0s - loss: 0.1783 - mae: 0.1783 - mse: 0.1404
# Epoch 7: mse improved from 0.14476 to 0.14044, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.1783 - mae: 0.1783 - mse: 0.1404 - val_loss: 0.2599 - val_mae: 0.2599 - val_mse: 0.2718
# Epoch 8/10
# 1400/1401 [============================>.] - ETA: 0s - loss: 0.1830 - mae: 0.1830 - mse: 0.1465
# Epoch 8: mse did not improve from 0.14044
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.1829 - mae: 0.1829 - mse: 0.1465 - val_loss: 0.2492 - val_mae: 0.2492 - val_mse: 0.2591
# Epoch 9/10
# 1401/1401 [==============================] - ETA: 0s - loss: 0.2568 - mae: 0.2568 - mse: 0.3072
# Epoch 9: mse did not improve from 0.14044
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.2568 - mae: 0.2568 - mse: 0.3072 - val_loss: 0.3475 - val_mae: 0.3475 - val_mse: 0.3899
# Epoch 10/10
# 1398/1401 [============================>.] - ETA: 0s - loss: 0.2660 - mae: 0.2660 - mse: 0.2637
# Epoch 10: mse did not improve from 0.14044
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.2658 - mae: 0.2658 - mse: 0.2634 - val_loss: 0.3122 - val_mae: 0.3122 - val_mse: 0.3408

# %%
#save model_u_LSTM_S
save_model(model_u_CNNLSTM_S,'/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_u_CNNLSTM_S.h5')
# Out:
# Deleted existing model: /content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_u_CNNLSTM_S.h5

# %%
#load model
model_u_CNNLSTM_S=load_model('/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_u_CNNLSTM_S.h5')

# %%
history_model(history_u_CNNLSTM_S)

# %%
def evalute_model(model,data,train,scaler,X_test,y_test,start,step_in,n_forecast,color_d):
 predictions=model.predict(X_test)
 predictions=scaler.inverse_transform(predictions)
 y_test=y_test.reshape(y_test.shape[0],y_test.shape[1])
 y_test=scaler.inverse_transform(y_test)
 for i in range(len(y_test)-1):
  bias=abs(y_test[i,1]-predictions[i,1])
  predictions[i,1]=y_test[i,1]-bias
 print(bias)
###############################
 plt.figure(figsize=(10,5))
 plt.plot(data.index[len(train)+start:len(train)+start+step_in+1],y_test[start:start+step_in+1,1],label='12 heure avant',color=color_d)
 plt.plot(data.index[len(train)+start+step_in:len(train)+start+step_in+n_forecast],y_test[start+step_in:start+step_in+n_forecast,1],label='6 heures après',color='green')
 plt.plot(data.index[len(train)+step_in+start:len(train)+n_forecast+start+step_in],predictions[start+step_in:start+step_in+n_forecast,1],linestyle='dashed',color='red',label='prévision_CNN-LSTM')
 plt.xlabel('Temps')
 plt.ylabel('Energie en (MW)')
 plt.legend()
 plt.title('Valeurs prévisionnelles vs Valeurs réelles')
 mae=mean_absolute_error(y_test,predictions)
 mse=mean_squared_error(y_test,predictions)
 rmse = np.sqrt(mse)
 mape = mean_absolute_percentage_error(y_test,predictions)
 print('mae=',mae)
 print('mse=',mse)
 print('rmse=',rmse)
 print('mape=',mape)


 return predictions

# %%
predictions_u_CNNLSTM_S=evalute_model(model_u_CNNLSTM_S,solar_data,train_S,sc_test_S,X_test_S,y_test_S,30,48,12,'orange')
# Out:
# 436/436 [==============================] - 3s 6ms/step
# 0.34260284900665283
# mae= 8.648959894180297
# mse= 91.7830840620688
# rmse= 9.580348848662496
# mape= 0.29625679817457445

# %%
history_u_CNNLSTM_W,model_u_CNNLSTM_W,model_summary=get_best_model(X_train_W,y_train_W,project_name='Wind power foreacasting_unvariate_CNNLSTM')
model_summary
# Out:
# Trial 10 Complete [00h 00m 23s]
# mse: 0.4700564742088318
#
# Best mse So Far: 0.4700564742088318
# Total elapsed time: 00h 03m 23s
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 95, 48)            144
#
#  max_pooling1d_2 (MaxPooling  (None, 95, 48)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 94, 64)            6208
#
#  max_pooling1d_3 (MaxPooling  (None, 94, 64)           0
#  1D)
#
#  cu_dnnlstm_2 (CuDNNLSTM)    (None, 94, 50)            23200
#
#  activation_1 (Activation)   (None, 94, 50)            0
#
#  cu_dnnlstm_3 (CuDNNLSTM)    (None, 150)               121200
#
#  dense_1 (Dense)             (None, 24)                3624
#
# =================================================================
# Total params: 154,376
# Trainable params: 154,376
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/5
# 932/934 [============================>.] - ETA: 0s - loss: 0.4681 - mae: 0.4681 - mse: 0.4789
# Epoch 1: mse improved from inf to 0.47818, saving model to best_model.h5
# 934/934 [==============================] - 16s 13ms/step - loss: 0.4676 - mae: 0.4676 - mse: 0.4782 - val_loss: 0.5672 - val_mae: 0.5672 - val_mse: 0.6336
# Epoch 2/5
# 931/934 [============================>.] - ETA: 0s - loss: 0.4157 - mae: 0.4157 - mse: 0.4133
# Epoch 2: mse improved from 0.47818 to 0.41281, saving model to best_model.h5
# 934/934 [==============================] - 11s 12ms/step - loss: 0.4154 - mae: 0.4154 - mse: 0.4128 - val_loss: 0.5562 - val_mae: 0.5562 - val_mse: 0.6138
# Epoch 3/5
# 931/934 [============================>.] - ETA: 0s - loss: 0.4105 - mae: 0.4105 - mse: 0.4081
# Epoch 3: mse improved from 0.41281 to 0.40768, saving model to best_model.h5
# 934/934 [==============================] - 11s 12ms/step - loss: 0.4104 - mae: 0.4104 - mse: 0.4077 - val_loss: 0.5548 - val_mae: 0.5548 - val_mse: 0.6089
# Epoch 4/5
# 933/934 [============================>.] - ETA: 0s - loss: 0.4090 - mae: 0.4090 - mse: 0.4059
# Epoch 4: mse improved from 0.40768 to 0.40566, saving model to best_model.h5
# 934/934 [==============================] - 12s 13ms/step - loss: 0.4089 - mae: 0.4089 - mse: 0.4057 - val_loss: 0.5564 - val_mae: 0.5564 - val_mse: 0.6137
# Epoch 5/5
# 934/934 [==============================] - ETA: 0s - loss: 0.4073 - mae: 0.4073 - mse: 0.4044
# Epoch 5: mse improved from 0.40566 to 0.40439, saving model to best_model.h5
# 934/934 [==============================] - 12s 13ms/step - loss: 0.4073 - mae: 0.4073 - mse: 0.4044 - val_loss: 0.5526 - val_mae: 0.5526 - val_mse: 0.6027

# %%
#save model_u_LSTM_W
save_model(model_u_LSTM_W,'/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_u_CNNLSTM_W.h5')
# Out:
# No existing model found at: /content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_u_CNNLSTM_W.h5

# %%
#load model
model_u_CNNLSTM_W=load_model('/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_u_CNNLSTM_W.h5')

# %%
history_model(history_u_CNNLSTM_W)

# %%
predictions_u_CNNLSTM_W=evalute_model(model_u_CNNLSTM_W,wind_data,train_W,sc_test_W,X_test_W,y_test_W,50,48,12,None)
# Out:
# 435/435 [==============================] - 2s 4ms/step
# 0.9217708349227891
# mae= 4.55396551823713
# mse= 56.94738500449543
# rmse= 7.546349117586294
# mape= 15311157454550.766

# %% [markdown]
# **Approche multivariée**

# %%
solar_data=first_prep('/content/drive/MyDrive/PV_Wind_Power_Forecasting_Hmidani_Hicham/Solar-station-site-1-_Nominal-capacity-50MW_.csv')
wind_data=first_prep('/content/drive/MyDrive/PV_Wind_Power_Forecasting_Hmidani_Hicham/Wind-farm-site-1-_Nominal-capacity-99MW_-_1_.csv')

# %%
def filter_features_by_correlation(df, label_name):
    # Calculer la matrice de corrélation entre les features et le label
    correlation_matrix = df.corr()

    # Sélectionner la colonne de corrélation avec le label
    label_correlation = correlation_matrix[label_name]
    correlation_threshold = abs(label_correlation).mean()


    # Filtrer les features dont le coefficient de corrélation avec le label dépasse la valeur seuil
    correlated_features = label_correlation[abs(label_correlation) > correlation_threshold].index.tolist()
    data=df[correlated_features]

    return data

# %%
solar_data_correlated=filter_features_by_correlation(solar_data,'Power (MW)')

# %%
solar_data_correlated

# %%
wind_data_correlated=filter_features_by_correlation(wind_data,'Power (MW)')

# %%
type(wind_data_correlated)

# %%
#Split the data into train and test for solar data
train_S_m=solar_data_correlated[:int(len(solar_data)*0.8)]
test_S_m=solar_data_correlated[int(len(solar_data)*0.8):]
#Split the data into train and test
train_W_m=wind_data_correlated[:int(len(wind_data)*0.8)]
test_W_m=wind_data_correlated[int(len(wind_data)*0.8):]

# %%
train_S_m.shape
# Out:
# (56140, 4)

# %%
#split to features and label
def split_features_label(data,label):
  label=data[[label]].copy()
  features=data.drop(label,axis=1)
  scaler=StandardScaler()
  features=scaler.fit_transform(features)
  label=scaler.fit_transform(label)
  return features,label,scaler

# %%
train_features_S,train_label_S,scaler_train_s=split_features_label(train_S_m,'Power (MW)')
test_features_S,test_label_S,scaler_test_s=split_features_label(test_S_m,'Power (MW)')

train_features_W,train_label_W,scaler_train_w=split_features_label(train_W_m,'Power (MW)')
test_features_W,test_label_W,scaler_test_w=split_features_label(test_W_m,'Power (MW)')

# %%
def split_sequences_2(features,label,step_in=960,step_out=12):
 X,y=[],[]
 for i in range(step_in,len(features)-step_out):
  X.append(features[i-step_in:i])
  y.append(label[i:i+step_out])
 X=np.array(X)
 y=np.array(y)
 return X,y

X_train_S,y_train_S=split_sequences_2(train_features_S,train_label_S,step_in=96,step_out=24)
X_test_S,y_test_S=split_sequences_2(test_features_S,test_label_S,step_in=96,step_out=24)


X_train_W,y_train_W=split_sequences_2(train_features_W,train_label_W,step_in=96,step_out=24)
X_test_W,y_test_W=split_sequences_2(test_features_W,test_label_W,step_in=96,step_out=24)

# %%
history_m_CNNLSTM_S,model_m_CNNLSTM_S,model_summary=get_best_model(X_train_S,y_train_S,project_name='solar power foreacasting_multivariat_CNNLSTM_1')
model_summary
# Out:
# Trial 10 Complete [00h 00m 16s]
# mse: 0.27316293120384216
#
# Best mse So Far: 0.253910094499588
# Total elapsed time: 00h 03m 36s
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 96, 32)            64
#
#  max_pooling1d_2 (MaxPooling  (None, 48, 32)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 46, 48)            4656
#
#  max_pooling1d_3 (MaxPooling  (None, 23, 48)           0
#  1D)
#
#  cu_dnnlstm_2 (CuDNNLSTM)    (None, 23, 100)           60000
#
#  activation_1 (Activation)   (None, 23, 100)           0
#
#  cu_dnnlstm_3 (CuDNNLSTM)    (None, 50)                30400
#
#  dense_1 (Dense)             (None, 24)                1224
#
# =================================================================
# Total params: 96,344
# Trainable params: 96,344
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 701/701 [==============================] - ETA: 0s - loss: 0.2765 - mae: 0.2765 - mse: 0.2682
# Epoch 1: mse improved from inf to 0.26818, saving model to best_model.h5
# 701/701 [==============================] - 10s 10ms/step - loss: 0.2765 - mae: 0.2765 - mse: 0.2682 - val_loss: 0.3125 - val_mae: 0.3125 - val_mse: 0.3710
# Epoch 2/20
# 694/701 [============================>.] - ETA: 0s - loss: 0.1999 - mae: 0.1999 - mse: 0.1618
# Epoch 2: mse improved from 0.26818 to 0.16087, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1992 - mae: 0.1992 - mse: 0.1609 - val_loss: 0.2661 - val_mae: 0.2661 - val_mse: 0.2933
# Epoch 3/20
# 700/701 [============================>.] - ETA: 0s - loss: 0.1826 - mae: 0.1826 - mse: 0.1429
# Epoch 3: mse improved from 0.16087 to 0.14282, saving model to best_model.h5
# 701/701 [==============================] - 7s 10ms/step - loss: 0.1825 - mae: 0.1825 - mse: 0.1428 - val_loss: 0.2483 - val_mae: 0.2483 - val_mse: 0.2618
# Epoch 4/20
# 696/701 [============================>.] - ETA: 0s - loss: 0.1762 - mae: 0.1762 - mse: 0.1374
# Epoch 4: mse improved from 0.14282 to 0.13695, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1759 - mae: 0.1759 - mse: 0.1370 - val_loss: 0.2398 - val_mae: 0.2398 - val_mse: 0.2518
# Epoch 5/20
# 700/701 [============================>.] - ETA: 0s - loss: 0.1717 - mae: 0.1717 - mse: 0.1337
# Epoch 5: mse improved from 0.13695 to 0.13369, saving model to best_model.h5
# 701/701 [==============================] - 7s 11ms/step - loss: 0.1716 - mae: 0.1716 - mse: 0.1337 - val_loss: 0.2355 - val_mae: 0.2355 - val_mse: 0.2464
# Epoch 6/20
# 695/701 [============================>.] - ETA: 0s - loss: 0.1699 - mae: 0.1699 - mse: 0.1320
# Epoch 6: mse improved from 0.13369 to 0.13140, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1694 - mae: 0.1694 - mse: 0.1314 - val_loss: 0.2293 - val_mae: 0.2293 - val_mse: 0.2391
# Epoch 7/20
# 700/701 [============================>.] - ETA: 0s - loss: 0.1675 - mae: 0.1675 - mse: 0.1297
# Epoch 7: mse improved from 0.13140 to 0.12966, saving model to best_model.h5
# 701/701 [==============================] - 7s 9ms/step - loss: 0.1674 - mae: 0.1674 - mse: 0.1297 - val_loss: 0.2253 - val_mae: 0.2253 - val_mse: 0.2340
# Epoch 8/20
# 701/701 [==============================] - ETA: 0s - loss: 0.1652 - mae: 0.1652 - mse: 0.1277
# Epoch 8: mse improved from 0.12966 to 0.12773, saving model to best_model.h5
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1652 - mae: 0.1652 - mse: 0.1277 - val_loss: 0.2256 - val_mae: 0.2256 - val_mse: 0.2344
# Epoch 9/20
# 701/701 [==============================] - ETA: 0s - loss: 0.1634 - mae: 0.1634 - mse: 0.1264
# Epoch 9: mse improved from 0.12773 to 0.12636, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1634 - mae: 0.1634 - mse: 0.1264 - val_loss: 0.2207 - val_mae: 0.2207 - val_mse: 0.2270
# Epoch 10/20
# 695/701 [============================>.] - ETA: 0s - loss: 0.1626 - mae: 0.1626 - mse: 0.1259
# Epoch 10: mse improved from 0.12636 to 0.12527, saving model to best_model.h5
# 701/701 [==============================] - 7s 10ms/step - loss: 0.1621 - mae: 0.1621 - mse: 0.1253 - val_loss: 0.2191 - val_mae: 0.2191 - val_mse: 0.2250
# Epoch 11/20
# 698/701 [============================>.] - ETA: 0s - loss: 0.1607 - mae: 0.1607 - mse: 0.1242
# Epoch 11: mse improved from 0.12527 to 0.12409, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1607 - mae: 0.1607 - mse: 0.1241 - val_loss: 0.2168 - val_mae: 0.2168 - val_mse: 0.2224
# Epoch 12/20
# 697/701 [============================>.] - ETA: 0s - loss: 0.1590 - mae: 0.1590 - mse: 0.1230
# Epoch 12: mse improved from 0.12409 to 0.12275, saving model to best_model.h5
# 701/701 [==============================] - 7s 10ms/step - loss: 0.1588 - mae: 0.1588 - mse: 0.1227 - val_loss: 0.2145 - val_mae: 0.2145 - val_mse: 0.2181
# Epoch 13/20
# 698/701 [============================>.] - ETA: 0s - loss: 0.1577 - mae: 0.1577 - mse: 0.1220
# Epoch 13: mse improved from 0.12275 to 0.12185, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1576 - mae: 0.1576 - mse: 0.1218 - val_loss: 0.2133 - val_mae: 0.2133 - val_mse: 0.2160
# Epoch 14/20
# 698/701 [============================>.] - ETA: 0s - loss: 0.1567 - mae: 0.1567 - mse: 0.1209
# Epoch 14: mse improved from 0.12185 to 0.12079, saving model to best_model.h5
# 701/701 [==============================] - 7s 10ms/step - loss: 0.1567 - mae: 0.1567 - mse: 0.1208 - val_loss: 0.2131 - val_mae: 0.2131 - val_mse: 0.2149
# Epoch 15/20
# 697/701 [============================>.] - ETA: 0s - loss: 0.1576 - mae: 0.1576 - mse: 0.1214
# Epoch 15: mse did not improve from 0.12079
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1574 - mae: 0.1574 - mse: 0.1211 - val_loss: 0.2121 - val_mae: 0.2121 - val_mse: 0.2115
# Epoch 16/20
# 700/701 [============================>.] - ETA: 0s - loss: 0.1559 - mae: 0.1559 - mse: 0.1201
# Epoch 16: mse improved from 0.12079 to 0.12007, saving model to best_model.h5
# 701/701 [==============================] - 7s 10ms/step - loss: 0.1558 - mae: 0.1558 - mse: 0.1201 - val_loss: 0.2133 - val_mae: 0.2133 - val_mse: 0.2128
# Epoch 17/20
# 698/701 [============================>.] - ETA: 0s - loss: 0.1543 - mae: 0.1543 - mse: 0.1187
# Epoch 17: mse improved from 0.12007 to 0.11856, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1543 - mae: 0.1543 - mse: 0.1186 - val_loss: 0.2114 - val_mae: 0.2114 - val_mse: 0.2083
# Epoch 18/20
# 701/701 [==============================] - ETA: 0s - loss: 0.1534 - mae: 0.1534 - mse: 0.1178
# Epoch 18: mse improved from 0.11856 to 0.11778, saving model to best_model.h5
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1534 - mae: 0.1534 - mse: 0.1178 - val_loss: 0.2107 - val_mae: 0.2107 - val_mse: 0.2058
# Epoch 19/20
# 699/701 [============================>.] - ETA: 0s - loss: 0.1527 - mae: 0.1527 - mse: 0.1171
# Epoch 19: mse improved from 0.11778 to 0.11701, saving model to best_model.h5
# 701/701 [==============================] - 6s 9ms/step - loss: 0.1526 - mae: 0.1526 - mse: 0.1170 - val_loss: 0.2120 - val_mae: 0.2120 - val_mse: 0.2066
# Epoch 20/20
# 696/701 [============================>.] - ETA: 0s - loss: 0.1521 - mae: 0.1521 - mse: 0.1165
# Epoch 20: mse improved from 0.11701 to 0.11610, saving model to best_model.h5
# 701/701 [==============================] - 6s 8ms/step - loss: 0.1518 - mae: 0.1518 - mse: 0.1161 - val_loss: 0.2160 - val_mae: 0.2160 - val_mse: 0.2096

# %%
#save model_u_LSTM_S
save_model(model_m_CNNLSTM_S,'/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_m_CNNLSTM_S.h5')
# Out:
# No existing model found at: /content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_m_CNNLSTM_S.h5

# %%
#load model
model_m_CNNLSTM_S=load_model('/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_m_CNNLSTM_S.h5')

# %%
history_model(history_m_CNNLSTM_S)

# %%
predictions_m_CNNLSTM_S=evalute_model(model_m_CNNLSTM_S,solar_data,train_S,sc_test_S,X_test_S,y_test_S,0,0,2880,'orange')
# Out:
# 435/435 [==============================] - 2s 5ms/step
# 0.6393476772308349
# mae= 2.891739857450754
# mse= 33.293739390909046
# rmse= 5.770072737055318
# mape= 1273486736129457.8

# %%
history_m_CNNLSTM_W,model_m_CNNLSTM_W,model_summary=get_best_model(X_train_W,y_train_W,project_name='Wind power foreacasting_multivariat_CNNLSTM_1')
model_summary
# Out:
# Trial 10 Complete [00h 00m 16s]
# mse: 0.6091181039810181
#
# Best mse So Far: 0.46218806505203247
# Total elapsed time: 00h 03m 20s
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv1d_2 (Conv1D)           (None, 96, 16)            32
#
#  max_pooling1d_2 (MaxPooling  (None, 96, 16)           0
#  1D)
#
#  conv1d_3 (Conv1D)           (None, 96, 48)            816
#
#  max_pooling1d_3 (MaxPooling  (None, 96, 48)           0
#  1D)
#
#  cu_dnnlstm_2 (CuDNNLSTM)    (None, 96, 100)           60000
#
#  activation_1 (Activation)   (None, 96, 100)           0
#
#  cu_dnnlstm_3 (CuDNNLSTM)    (None, 50)                30400
#
#  dense_1 (Dense)             (None, 24)                1224
#
# =================================================================
# Total params: 92,472
# Trainable params: 92,472
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/20
# 1400/1401 [============================>.] - ETA: 0s - loss: 0.4601 - mae: 0.4601 - mse: 0.4777
# Epoch 1: mse improved from inf to 0.47750, saving model to best_model.h5
# 1401/1401 [==============================] - 21s 13ms/step - loss: 0.4600 - mae: 0.4600 - mse: 0.4775 - val_loss: 0.5664 - val_mae: 0.5664 - val_mse: 0.6327
# Epoch 2/20
# 1399/1401 [============================>.] - ETA: 0s - loss: 0.4120 - mae: 0.4120 - mse: 0.4090
# Epoch 2: mse improved from 0.47750 to 0.40864, saving model to best_model.h5
# 1401/1401 [==============================] - 19s 14ms/step - loss: 0.4118 - mae: 0.4118 - mse: 0.4086 - val_loss: 0.5594 - val_mae: 0.5594 - val_mse: 0.6213
# Epoch 3/20
# 1401/1401 [==============================] - ETA: 0s - loss: 0.4078 - mae: 0.4078 - mse: 0.4046
# Epoch 3: mse improved from 0.40864 to 0.40458, saving model to best_model.h5
# 1401/1401 [==============================] - 20s 14ms/step - loss: 0.4078 - mae: 0.4078 - mse: 0.4046 - val_loss: 0.5575 - val_mae: 0.5575 - val_mse: 0.6184
# Epoch 4/20
# 1401/1401 [==============================] - ETA: 0s - loss: 0.4056 - mae: 0.4056 - mse: 0.4028
# Epoch 4: mse improved from 0.40458 to 0.40276, saving model to best_model.h5
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.4056 - mae: 0.4056 - mse: 0.4028 - val_loss: 0.5559 - val_mae: 0.5559 - val_mse: 0.6135
# Epoch 5/20
# 1401/1401 [==============================] - ETA: 0s - loss: 0.4055 - mae: 0.4055 - mse: 0.4022
# Epoch 5: mse improved from 0.40276 to 0.40215, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.4055 - mae: 0.4055 - mse: 0.4022 - val_loss: 0.5543 - val_mae: 0.5543 - val_mse: 0.6113
# Epoch 6/20
# 1400/1401 [============================>.] - ETA: 0s - loss: 0.4027 - mae: 0.4027 - mse: 0.4004
# Epoch 6: mse improved from 0.40215 to 0.40031, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.4026 - mae: 0.4026 - mse: 0.4003 - val_loss: 0.5530 - val_mae: 0.5530 - val_mse: 0.6086
# Epoch 7/20
# 1397/1401 [============================>.] - ETA: 0s - loss: 0.4016 - mae: 0.4016 - mse: 0.3989
# Epoch 7: mse improved from 0.40031 to 0.39842, saving model to best_model.h5
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.4014 - mae: 0.4014 - mse: 0.3984 - val_loss: 0.5517 - val_mae: 0.5517 - val_mse: 0.6037
# Epoch 8/20
# 1398/1401 [============================>.] - ETA: 0s - loss: 0.4010 - mae: 0.4010 - mse: 0.3965
# Epoch 8: mse improved from 0.39842 to 0.39588, saving model to best_model.h5
# 1401/1401 [==============================] - 16s 12ms/step - loss: 0.4006 - mae: 0.4006 - mse: 0.3959 - val_loss: 0.5515 - val_mae: 0.5515 - val_mse: 0.6055
# Epoch 9/20
# 1401/1401 [==============================] - ETA: 0s - loss: 0.3995 - mae: 0.3995 - mse: 0.3964
# Epoch 9: mse did not improve from 0.39588
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.3995 - mae: 0.3995 - mse: 0.3964 - val_loss: 0.5533 - val_mae: 0.5533 - val_mse: 0.6107
# Epoch 10/20
# 1396/1401 [============================>.] - ETA: 0s - loss: 0.3984 - mae: 0.3984 - mse: 0.3959
# Epoch 10: mse improved from 0.39588 to 0.39552, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.3984 - mae: 0.3984 - mse: 0.3955 - val_loss: 0.5566 - val_mae: 0.5566 - val_mse: 0.6185
# Epoch 11/20
# 1399/1401 [============================>.] - ETA: 0s - loss: 0.4016 - mae: 0.4016 - mse: 0.4019
# Epoch 11: mse did not improve from 0.39552
# 1401/1401 [==============================] - 17s 12ms/step - loss: 0.4015 - mae: 0.4015 - mse: 0.4016 - val_loss: 0.5529 - val_mae: 0.5529 - val_mse: 0.6114
# Epoch 12/20
# 1401/1401 [==============================] - ETA: 0s - loss: 0.3978 - mae: 0.3978 - mse: 0.3954
# Epoch 12: mse improved from 0.39552 to 0.39542, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.3978 - mae: 0.3978 - mse: 0.3954 - val_loss: 0.5507 - val_mae: 0.5507 - val_mse: 0.6039
# Epoch 13/20
# 1399/1401 [============================>.] - ETA: 0s - loss: 0.3966 - mae: 0.3966 - mse: 0.3937
# Epoch 13: mse improved from 0.39542 to 0.39337, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.3965 - mae: 0.3965 - mse: 0.3934 - val_loss: 0.5492 - val_mae: 0.5492 - val_mse: 0.5984
# Epoch 14/20
# 1399/1401 [============================>.] - ETA: 0s - loss: 0.3962 - mae: 0.3962 - mse: 0.3928
# Epoch 14: mse improved from 0.39337 to 0.39245, saving model to best_model.h5
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.3960 - mae: 0.3960 - mse: 0.3924 - val_loss: 0.5507 - val_mae: 0.5507 - val_mse: 0.6029
# Epoch 15/20
# 1400/1401 [============================>.] - ETA: 0s - loss: 0.3946 - mae: 0.3946 - mse: 0.3919
# Epoch 15: mse improved from 0.39245 to 0.39175, saving model to best_model.h5
# 1401/1401 [==============================] - 16s 12ms/step - loss: 0.3945 - mae: 0.3945 - mse: 0.3918 - val_loss: 0.5498 - val_mae: 0.5498 - val_mse: 0.5982
# Epoch 16/20
# 1400/1401 [============================>.] - ETA: 0s - loss: 0.3936 - mae: 0.3936 - mse: 0.3897
# Epoch 16: mse improved from 0.39175 to 0.38954, saving model to best_model.h5
# 1401/1401 [==============================] - 19s 13ms/step - loss: 0.3935 - mae: 0.3935 - mse: 0.3895 - val_loss: 0.5505 - val_mae: 0.5505 - val_mse: 0.6021
# Epoch 17/20
# 1398/1401 [============================>.] - ETA: 0s - loss: 0.3937 - mae: 0.3937 - mse: 0.3910
# Epoch 17: mse did not improve from 0.38954
# 1401/1401 [==============================] - 18s 13ms/step - loss: 0.3934 - mae: 0.3934 - mse: 0.3904 - val_loss: 0.5512 - val_mae: 0.5512 - val_mse: 0.6018
# Epoch 18/20
# 1396/1401 [============================>.] - ETA: 0s - loss: 0.3912 - mae: 0.3912 - mse: 0.3870
# Epoch 18: mse improved from 0.38954 to 0.38655, saving model to best_model.h5
# 1401/1401 [==============================] - 16s 12ms/step - loss: 0.3910 - mae: 0.3910 - mse: 0.3865 - val_loss: 0.5531 - val_mae: 0.5531 - val_mse: 0.6023
# Epoch 19/20
# 1400/1401 [============================>.] - ETA: 0s - loss: 0.3921 - mae: 0.3921 - mse: 0.3881
# Epoch 19: mse did not improve from 0.38655
# 1401/1401 [==============================] - 16s 12ms/step - loss: 0.3920 - mae: 0.3920 - mse: 0.3880 - val_loss: 0.5569 - val_mae: 0.5569 - val_mse: 0.6075
# Epoch 20/20
# 1398/1401 [============================>.] - ETA: 0s - loss: 0.3907 - mae: 0.3907 - mse: 0.3865
# Epoch 20: mse improved from 0.38655 to 0.38591, saving model to best_model.h5
# 1401/1401 [==============================] - 16s 12ms/step - loss: 0.3904 - mae: 0.3904 - mse: 0.3859 - val_loss: 0.5585 - val_mae: 0.5585 - val_mse: 0.6203

# %%
#save model_u_LSTM_W
save_model(model_m_CNNLSTM_W,'/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_m_CNNLSTM_W.h5')
# Out:
# Deleted existing model: /content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_m_CNNLSTM_W.h5

# %%
#load model
model_m_CNNLSTM_W=load_model('/content/drive/MyDrive/PV-Wind_Forecasting_Hmidani-Hicham/model_m_CNNLSTM_W.h5')

# %%
history_model(history_m_CNNLSTM_W)

# %%
predictions_m_CNNLSTM_W=evalute_model(model_m_CNNLSTM_W,wind_data,train_W,sc_test_W,X_test_W,y_test_W,35,48,24,None)
# Out:
# 435/435 [==============================] - 3s 5ms/step
# 0.7067172765731797
# mae= 10.014865967361704
# mse= 269.3798916895071
# rmse= 16.41279658344388
# mape= 234561002478930.6

# %% [markdown]
# out of project

# %%
# Forecasting Future Sales
# Assuming 'your_dataframe' contains all the data, not just the training set
X_future = your_dataframe['sales'][-n_steps:].values.reshape(1, n_steps, 1)
future_forecast = []
for i in range(n):  # Replace 'n' with the number of future steps to forecast
    y_pred = model.predict(X_future)
    future_forecast.append(y_pred[0, 0])
    X_future = np.append(X_future[:, 1:, :], y_pred, axis=1)

# %%
from statsmodels.tsa.seasonal import STL

# Example time series data
# Replace this with your own time series data (e.g., load from a CSV or Excel file)
data = pd.Series([40, 42, 43, 48, 50, 45, 44, 47, 50, 55, 60, 63, 62, 65, 70, 72, 75, 80, 82, 85])

# Perform seasonal decomposition using STL
stl = STL(data, seasonal=13)  # Set seasonal period (here, 13 observations per season)
result = stl.fit()

# Extract the trend, seasonal, and residual components
trend = result.trend
seasonal = result.seasonal
residual = result.resid

# Plot the original time series and its components
plt.figure(figsize=(10, 6))
plt.subplot(4, 1, 1)
plt.plot(data, label='Original Data')
plt.legend()

plt.subplot(4, 1, 2)
plt.plot(trend, label='Trend')
plt.legend()

plt.subplot(4, 1, 3)
plt.plot(seasonal, label='Seasonal')
plt.legend()

plt.subplot(4, 1, 4)
plt.plot(residual, label='Residual')
plt.legend()

plt.tight_layout()
plt.show()
